# %% [markdown]
# # 1 - Data

# %% [markdown]
# ## Imports

# %%
from os import path
import sys
# Online Path
# sys.path.append("/home/ubuntu/Online_Bots")
# Offline Path
sys.path.append("D:\Projets_Python\Online_Bots")
import pandas_ta as ta
from datetime import datetime, timedelta

from strategies.Wallet_and_positions_manager import get_wallet, get_positions
from strategies.df_manager_bitget import get_and_manage_df_bitget, load_datas_from_file, save_datas_to_file
from strategies.Trades_Manager import get_closure_order, report_results, search_to_open_position, search_to_move_sl
# save and load datas directory Offline
save_load_datas_directory = r'D:\Projets_Python\Online_Bots\strategies\Datas'
# # save and load datas directory Online
# save_load_datas_directory = r'/home/ubuntu/Online_Bots/strategies/Datas'

# %% [markdown]
# ## Time

# %%
now = datetime.utcnow()

# Start timer
start_time = now

current_time = now.strftime("%d-%m-%Y %H:%M:%S")
print("                                         _______________________________________________________                                       ")

print("                                         --- Start Execution Time :", current_time, "UTC ---")
# Out:
#                                          _______________________________________________________
#                                          --- Start Execution Time : 04-12-2023 11:00:06 UTC ---

# %% [markdown]
# ## Input

# %%
production = True

# Real account
# marginCoin = 'ETH'
# contrepartie= "USD"
# productType= "DMCBL"

# # Demo account
marginCoin = 'SETH'
contrepartie= "SUSD"
# sdmcbl Universal margin simulation perpetual contract
productType= "SDMCBL"

# Money Management
mysize = 0.99
leverage = 2
stop_loss = 40
trailing_stop = 1.8
take_profit = 150

# nb of candle to check for find lowest
lowest_low_nb = 5

symbol = marginCoin+contrepartie+"_"+productType

# Setup : date start / date end 
# date = obj date
from_date = "20-9-2023"+" 0:00:00" # str
# from_date str --> obj_from_date
obj_from_date = datetime.strptime(from_date, "%d-%m-%Y %H:%M:%S") # objet

# objet manual for now
# to_date = "20-9-2023"+" 17:00:00" # str
# # from_date str --> obj_from_date
# obj_to_now = datetime.strptime(to_date, "%d-%m-%Y %H:%M:%S") # objet
# objet automatic for now
obj_to_now = now 

# Intervals short term
interval = "5m"
orderType='market'

# Intervals long term
interval2 = "1Dutc"
obj_from_date2=(obj_to_now- timedelta(days=900))

# final data filename
df_filename = symbol + "_" + interval + ".xlsx"
print(f"--- {symbol} {interval} Leverage x {leverage} ---")

holdSide = ["long"]
# Out:
# --- SETHSUSD_SDMCBL 5m Leverage x 2 ---

# %% [markdown]
# ## Datas

# %%
# Download datas from df manager
df = get_and_manage_df_bitget(symbol, interval, obj_from_date, obj_to_now, df_filename, save_load_datas_directory, sheet_name='Price_History')
print("                                         -----------------------------------------------------                                       ")

# Download datas Weekly from df manager
df2 = get_and_manage_df_bitget(symbol, interval2, obj_from_date2, obj_to_now, df_filename, save_load_datas_directory, sheet_name='Long_Price_History')
print("                                         -----------------------------------------------------                                       ")

# Download datas from file
df_trades_loaded = load_datas_from_file(df_filename, save_load_datas_directory, sheet_name='Trades_Results')
# Out:
# No data to add before the date of : 2023-09-20 00:00:00
# Update 8395 candles at the end of the database, from 2023-11-05 07:20:00 to 2023-12-04 10:55:00
# Downloading price datas:  11%|█         | 1/9 [00:00<00:03,  2.44it/s]
642.1","53105661.56"],["1701043200000","2062.63","2071.36","1985.05","2027.76","35741.6","72459952.303"],["1701129600000","2027.76","2076.22","1993.8","2046.8","36748.3","74788527.182"],["1701216000000","2046.8","2073.32","2017.62","2029.2","30907.3","63189985.44"],["1701302400000","2029.2","2054.78","2018.87","2052.28","26008.5","52937500.21"],["1701388800000","2052.28","2110.5","2043.07","2085.33","29989.4","62575255.108"],["1701475200000","2085.33","2189.47","2084.36","2166.72","20965.2","44490840.209"],["1701561600000","2166.72","2216.89","2148","2191.51","18742.8","40654644.358"]]
# status: 200
# Number of planned lines = 900
# Actual number of rows in the dataframes = 504
# 396 rows are missing
# Check your dataframe
#
# Number of duplicates in the index before correction : 1
# Number of duplicates in the index after correction : 0
#                                          -----------------------------------------------------

# %% [markdown]
# # 2 - Define your signal function

# %% [markdown]
# ## Indicators

# %%
df
# Out:
#                         open     high      low    close  volume   iloc  \
# date
# 2023-09-20 00:00:00  1642.73  1644.82  1642.03  1643.97    57.6      0
# 2023-09-20 00:05:00  1643.97  1643.97  1641.34  1641.82    36.2      1
# 2023-09-20 00:10:00  1641.82  1645.43  1641.73  1643.40    63.8      2
# 2023-09-20 00:15:00  1643.40  1645.32  1642.38  1644.33    57.1      3
# 2023-09-20 00:20:00  1644.33  1644.33  1641.04  1642.99    53.2      4
# ...                      ...      ...      ...      ...     ...    ...
# 2023-12-04 10:35:00  2257.59  2264.92  2257.24  2259.67   113.2  21727
# 2023-12-04 10:40:00  2259.67  2265.24  2258.02  2261.13    50.3  21728
# 2023-12-04 10:45:00  2261.13  2273.07  2259.55  2266.93   454.8  21729
# 2023-12-04 10:50:00  2266.93  2274.88  2264.22  2266.84   162.7  21730
# 2023-12-04 10:55:00  2266.84  2268.60  2258.99  2259.23    89.9  21731
#
#                     macd_week macd_day macd_4h macd_1h macd_15m macd_5m
# date
# 2023-09-20 00:00:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-09-20 00:05:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-09-20 00:10:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-09-20 00:15:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-09-20 00:20:00       NaN      NaN     NaN     NaN      NaN     NaN
# ...                       ...      ...     ...     ...      ...     ...
# 2023-12-04 10:35:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-12-04 10:40:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-12-04 10:45:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-12-04 10:50:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-12-04 10:55:00       NaN      NaN     NaN     NaN      NaN     NaN
#
# [21732 rows x 12 columns]

# %%
df2.tail(30)
# Out:
#                open     high      low    close   volume  iloc
# date
# 2023-11-04  1833.52  1872.79  1824.90  1857.21  33693.1   473
# 2023-11-05  1857.21  1917.55  1848.01  1893.19  41033.2   474
# 2023-11-06  1893.19  1917.20  1871.25  1903.91  32880.5   475
# 2023-11-07  1903.91  1910.18  1850.70  1886.04  48247.1   476
# 2023-11-08  1886.04  1908.03  1874.17  1889.27  34360.3   477
# 2023-11-09  1889.27  2133.91  1883.36  2119.72  66410.3   478
# 2023-11-10  2119.72  2138.74  2064.36  2079.91  54173.7   479
# 2023-11-11  2079.91  2092.60  2030.09  2052.57  44358.5   480
# 2023-11-12  2052.57  2069.68  2013.93  2047.34  30781.9   481
# 2023-11-13  2047.34  2120.00  2030.05  2052.04  44771.8   482
# 2023-11-14  2052.04  2065.85  1923.87  1979.75  47043.1   483
# 2023-11-15  1979.75  2064.40  1966.59  2058.16  35647.4   484
# 2023-11-16  2058.16  2090.72  1937.95  1960.13  51960.3   485
# 2023-11-17  1960.13  1991.74  1905.46  1961.57  37984.7   486
# 2023-11-18  1961.57  1972.33  1916.73  1961.52  23722.9   487
# 2023-11-19  1961.52  2016.86  1942.41  2010.21  37383.2   488
# 2023-11-20  2010.21  2067.82  1993.96  2020.56  34259.1   489
# 2023-11-21  2020.56  2036.09  1931.10  1931.50  39027.8   490
# 2023-11-22  1931.50  2091.98  1927.53  2061.55  39821.7   491
# 2023-11-23  2061.55  2089.31  2038.91  2062.49  29676.1   492
# 2023-11-24  2062.49  2133.13  2057.21  2079.57  34714.5   493
# 2023-11-25  2079.57  2091.46  2064.15  2084.12  24566.9   494
# 2023-11-26  2084.12  2095.17  2033.96  2062.63  25642.1   495
# 2023-11-27  2062.63  2071.36  1985.05  2027.76  35741.6   496
# 2023-11-28  2027.76  2076.22  1993.80  2046.80  36748.3   497
# 2023-11-29  2046.80  2073.32  2017.62  2029.20  30907.3   498
# 2023-11-30  2029.20  2054.78  2018.87  2052.28  26008.5   499
# 2023-12-01  2052.28  2110.50  2043.07  2085.33  29989.4   500
# 2023-12-02  2085.33  2189.47  2084.36  2166.72  20965.2   501
# 2023-12-03  2166.72  2216.89  2148.00  2191.51  18742.8   502

# %%
# Calculate MACD for different timeframes .shift(-3, freq='H') because df = sofia time not UTC
macd_5m = ta.macd(df['close']).fillna(0).to_numpy()
macd_15m = ta.macd(df.resample('15min').last()['close']).fillna(0).to_numpy()
macd_1h = ta.macd(df.resample('1H').last()['close'], offset=1).fillna(0).to_numpy()
macd_4h = ta.macd(df.resample('4H').last()['close'], offset=1).fillna(0).to_numpy() # minimum 6000 5 Min

# macd_day = ta.macd(df.resample(('D')).last()['close'], offset=1).fillna(0).to_numpy()
macd_day = ta.macd(df2['close']).fillna(0).to_numpy() # minimum 770 D
macd_week = ta.macd(df2.resample('W').last()['close'], offset=None).fillna(0).to_numpy() # minimum 110 W
macd_week[-1:-6:-1]
# Out:
# array([[ 79.39880112,  51.93814213,  27.46065899],
#        [ 56.29094473,  41.81482128,  14.47612346],
#        [ 39.10046702,  35.07804889,   4.02241814],
#        [ 21.92774141,  26.6748355 ,  -4.74709409],
#        [ -4.09035916,   7.3254438 , -11.41580296]])

# %% [markdown]
# ## Buy or Sell Signal

# %%
# Signal for MACD open or not pour DF

# TRUE = MACD AU DESSUS de SIGNAL
indicators_name=["macd_week", "macd_day", "macd_4h", "macd_1h", "macd_15m", "macd_5m"]
indicators_list=(macd_week, macd_day, macd_4h, macd_1h, macd_15m, macd_5m)

def cross_macd(df, indicators_list, indicators_name, candle_back):
    results = []
    dt = df.copy()
    for i in indicators_list:
        if i[candle_back][0] > i[candle_back][2]:
            results.append(True)
        else:
            results.append(False)
    result_signals = dict(zip(indicators_name, results))
    dt.loc[dt.index[candle_back], result_signals.keys()] = result_signals.values()
    return dt

# %%
# # Test on x last candles
# x_last_candles = 20
# # print(x_last_candles+1)
# for i in range(-2,-x_last_candles-1,-1):
#     df = cross_macd(df, indicators_list, indicators_name, candle_back=i)

# %%
# check and save last candles for each Timeframes
df = cross_macd(df, indicators_list, indicators_name, candle_back=-1)

# %% [markdown]
# # 3 - Wallets and Positions

# %% [markdown]
# ### Wallet

# %%
# get wallet available
wallet_available = get_wallet(productType)
# Out:
# response :  {"code":"00000","msg":"success","requestTime":1701687612783,"data":[{"marginCoin":"SETH","locked":"0","available":"4.52062042","crossMaxAvailable":"4.52062042","fixedMaxAvailable":"4.52062042","maxTransferOut":"4.52062042","equity":"4.52062042","usdtEquity":"10224.187232044436","btcEquity":"0.243376878817","crossRiskRate":"0","unrealizedPL":"0","bonus":"0","crossedUnrealizedPL":null,"isolatedUnrealizedPL":null},{"marginCoin":"SEOS","locked":"0","available":"100","crossMaxAvailable":"100","fixedMaxAvailable":"100","maxTransferOut":"100","equity":"100","usdtEquity":"72.2906","btcEquity":"0.001720807747","crossRiskRate":"0","unrealizedPL":"0","bonus":"0","crossedUnrealizedPL":null,"isolatedUnrealizedPL":null},{"marginCoin":"SBTC","locked":"0","available":"0.99748324","crossMaxAvailable":"0.99748324","fixedMaxAvailable":"0.99748324","maxTransferOut":"0.99748324","equity":"0.99748324","usdtEquity":"41903.962021542222","btcEquity":"0.997483247853","crossRiskRate":"0","unrealizedPL":"0","bonus":"0","crossedUnrealizedPL":null,"isolatedUnrealizedPL":null}]}
# status: 200

# %% [markdown]
# ### Positions

# %%
# Check if position open or not
open_position = get_positions(productType, marginCoin)
# Out:
# response :  {"code":"00000","msg":"success","requestTime":1701687613150,"data":[]}
# status: 200

# %% [markdown]
# Somme de départ avant test = Wallet Available ETH : 0.10698140 = 197.6305 $
# Mon taux de frais
# Maker 0.018%, Taker 0.054%

# %% [markdown]
# # 4 - Matrix

# %% [markdown]
# ## Data for backtest (to delete)

# %%
df.tail(5)
# Out:
#                         open     high      low    close  volume   iloc  \
# date
# 2023-12-04 10:35:00  2257.59  2264.92  2257.24  2259.67   113.2  21727
# 2023-12-04 10:40:00  2259.67  2265.24  2258.02  2261.13    50.3  21728
# 2023-12-04 10:45:00  2261.13  2273.07  2259.55  2266.93   454.8  21729
# 2023-12-04 10:50:00  2266.93  2274.88  2264.22  2266.84   162.7  21730
# 2023-12-04 10:55:00  2266.84  2268.60  2258.99  2259.23    89.9  21731
#
#                     macd_week macd_day macd_4h macd_1h macd_15m macd_5m
# date
# 2023-12-04 10:35:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-12-04 10:40:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-12-04 10:45:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-12-04 10:50:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-12-04 10:55:00      True     True    True    True    False    True

# %%
# backtest bench

# Ligne -3
# df["macd_week"][-3] = True
# df["macd_day"][-3] = False
# df["macd_4h"][-3] = True
# df["macd_1h"][-3] = True
# df["macd_15m"][-3] = True
# df["macd_5m"][-3] = True
# df["Position_ouverte"][-3] = "4h"

# # Ligne -2
df["macd_week"][-2] = True
df["macd_day"][-2] = False
df["macd_4h"][-2] = True
df["macd_1h"][-2] = False
df["macd_15m"][-2] = True
df["macd_5m"][-2] = True
# df["Position_ouverte"][-2] = "4h"

# # Ligne -1
df["macd_week"][-1] = True
df["macd_day"][-1] = True
df["macd_4h"][-1] = True
df["macd_1h"][-1] = True
df["macd_15m"][-1] = True
df["macd_5m"][-1] = True
# df["Position_ouverte"][-1] = "day"

# df_trades_loaded["timeframe"][-1] = "15m"
# df["macd_day"][-7] = False
# print(df["macd_week"][-2])
# Out:
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["macd_week"][-2] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:13: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df["macd_week"][-2] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["macd_day"][-2] = False
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:14: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df["macd_day"][-2] = False
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["macd_4h"][-2] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:15: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df["macd_4h"][-2] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["macd_1h"][-2] = False
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:16: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df["macd_1h"][-2] = False
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["macd_15m"][-2] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:17: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df["macd_15m"][-2] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["macd_5m"][-2] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:18: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df["macd_5m"][-2] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["macd_week"][-1] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:22: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df["macd_week"][-1] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["macd_day"][-1] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:23: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df["macd_day"][-1] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["macd_4h"][-1] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:24: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df["macd_4h"][-1] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["macd_1h"][-1] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:25: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df["macd_1h"][-1] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["macd_15m"][-1] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:26: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df["macd_15m"][-1] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["macd_5m"][-1] = True
# C:\Users\cpiro\AppData\Local\Temp\ipykernel_24240\83284780.py:27: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   df["macd_5m"][-1] = True

# %%
df.tail(5)
# Out:
#                         open     high      low    close  volume   iloc  \
# date
# 2023-12-04 10:35:00  2257.59  2264.92  2257.24  2259.67   113.2  21727
# 2023-12-04 10:40:00  2259.67  2265.24  2258.02  2261.13    50.3  21728
# 2023-12-04 10:45:00  2261.13  2273.07  2259.55  2266.93   454.8  21729
# 2023-12-04 10:50:00  2266.93  2274.88  2264.22  2266.84   162.7  21730
# 2023-12-04 10:55:00  2266.84  2268.60  2258.99  2259.23    89.9  21731
#
#                     macd_week macd_day macd_4h macd_1h macd_15m macd_5m
# date
# 2023-12-04 10:35:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-12-04 10:40:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-12-04 10:45:00       NaN      NaN     NaN     NaN      NaN     NaN
# 2023-12-04 10:50:00      True    False    True   False     True    True
# 2023-12-04 10:55:00      True     True    True    True     True    True

# %% [markdown]
# ## Matrix

# %%
from strategies.Connect_to_Bitget_Serveur import Order, Plan, Market, Account

contracts = Market.index(symbol)["data"]['index']
contracts
# found_long_market_price = Market.fills(symbol, limit="1")['data'][0]['price']
# found_long_market_price
# Out:
# response :  {"code":"00000","msg":"success","requestTime":1701687613514,"data":{"symbol":"SETHSUSD_SDMCBL","index":"2261.677885","timestamp":"1701687613519"}}
# status: 200
# '2261.677885'

# %%
if open_position:
    search_to_move_sl(df, symbol, marginCoin, lowest_low_nb, production, trailing_stop, holdSide, indicators_name, df_trades_loaded, candle_back_1=-1, candle_back_2=-2)
    
if not open_position:
    if df_trades_loaded is not None and df_trades_loaded["action"].iloc[-1] == "open":
        # 1- search first if positions was closed on previous candle by SL or TP
        closed_order = get_closure_order(symbol, df_trades_loaded, marginCoin, wallet_available)

        if closed_order is not None:
            # 2- Generate trade report
            report_to_save = report_results(df_trades_loaded, closed_order, indicators_name, marginCoin)
            # 3-save
            report_saved = save_datas_to_file(df_filename, report_to_save, save_load_datas_directory, sheet_name="Trades_Results")

    new_df_trades_saved = search_to_open_position(df, df_filename, symbol, leverage, mysize, take_profit, stop_loss, indicators_name, wallet_available, production, holdSide, marginCoin, save_load_datas_directory)
# Out:
# No active position
# Crossover macd_day Bullish
# macd_day open, take position macd_day
# response :  {"code":"00000","msg":"success","requestTime":1701687613842,"data":{"symbol":"SETHSUSD_SDMCBL","marginCoin":"SETH","longLeverage":5,"shortLeverage":5,"crossMarginLeverage":5,"marginMode":"crossed"}}
# status: 200
# Leverage level set to 1:5
# response :  {"code":"00000","msg":"success","requestTime":1701687614155,"data":[{"tradeId":"1115524183141462017","price":"2263.24","size":"1.5","side":"buy","timestamp":"1701687611375","symbol":"SETHSUSD_SDMCBL"}]}
# status: 200
# response :  {"code":"40762","msg":"The order size is greater than the max open size","requestTime":1701687614477,"data":null}
# status: 400
# ---------------------------------------------------------------------------
# BitgetAPIException                        Traceback (most recent call last)
# d:\Projets_Python\Online_Bots\strategies\MACD_Timeframes_Bot_online.ipynb Cell 32 line 1
#      <a href='vscode-notebook-cell:/d%3A/Projets_Python/Online_Bots/strategies/MACD_Timeframes_Bot_online.ipynb#X43sZmlsZQ%3D%3D?line=11'>12</a>         # 3-save
#      <a href='vscode-notebook-cell:/d%3A/Projets_Python/Online_Bots/strategies/MACD_Timeframes_Bot_online.ipynb#X43sZmlsZQ%3D%3D?line=12'>13</a>         report_saved = save_datas_to_file(df_filename, report_to_save, save_load_datas_directory, sheet_name="Trades_Results")
# ---> <a href='vscode-notebook-cell:/d%3A/Projets_Python/Online_Bots/strategies/MACD_Timeframes_Bot_online.ipynb#X43sZmlsZQ%3D%3D?line=14'>15</a> new_df_trades_saved = search_to_open_position(df, df_filename, symbol, leverage, mysize, take_profit, stop_loss, indicators_name, wallet_available, production, holdSide, marginCoin, save_load_datas_directory)
#
# File D:\Projets_Python\Online_Bots\strategies\Trades_Manager.py:166, in search_to_open_position(df, df_filename, symbol, leverage, mysize, take_profit, stop_loss, indicators_name, wallet_available, production, holdSide, marginCoin, save_load_datas_directory)
#     163 if wallet_available[marginCoin] > 0.1: # try if enough money for this trade
#     164     if production:
#     165         # trade opening
# --> 166         new_df_trades =  process_to_open_trade(symbol, marginCoin, leverage, timeframe, wallet_available, mysize, holdSide, take_profit, stop_loss)
#     167         if new_df_trades is not None:
#     168             df_trades_loaded = load_datas_from_file(df_filename, save_load_datas_directory, sheet_name='Trades_Results')
#
# File D:\Projets_Python\Online_Bots\strategies\Trades_Manager.py:119, in process_to_open_trade(symbol, marginCoin, leverage, timeframe, wallet_available, mysize, holdSide, take_profit, stop_loss)
#     117     new_leverage = set_leverage(symbol, marginCoin, leverage, holdSide='long') # leverage
#     118 trade_setup = setup_trade(symbol, wallet_available, marginCoin, mysize, new_leverage) # market_price_now, long_quantity_in_eth, trade_size
# --> 119 new_order_ref = send_order_to_open_trade(symbol, marginCoin, trade_setup, holdSide, take_profit, stop_loss) # new_order
#     120 order_id = save_trade_id(new_order_ref) # order ID
#     121 # fonction track trades
#
# File D:\Projets_Python\Online_Bots\strategies\Trades_Manager.py:48, in send_order_to_open_trade(symbol, marginCoin, trade_setup, holdSide, take_profit, stop_loss)
#      47 def send_order_to_open_trade(symbol, marginCoin, trade_setup, holdSide, take_profit, stop_loss):
# ---> 48     new_order = Order.place_order(
#      49     symbol,
#      50     marginCoin,
#      51     size=str(trade_setup[1]),
#      52     side="open_"+str(holdSide[0]),
#      53     orderType='market',
#      54     clientOrderId=None,
#      55     price='',
#      56     timeInForceValue='normal',
#      57     presetTakeProfitPrice=str(trade_setup[0]+take_profit),
#      58     presetStopLossPrice=str(trade_setup[0]-stop_loss)
#      59     )
#      60     return new_order
#
# File D:\Projets_Python\Online_Bots\bitget\mix\order_api.py:36, in OrderApi.place_order(self, symbol, marginCoin, size, side, orderType, clientOrderId, price, timeInForceValue, presetTakeProfitPrice, presetStopLossPrice)
#      34     params["presetTakeProfitPrice"] = presetTakeProfitPrice
#      35     params["presetStopLossPrice"] = presetStopLossPrice
# ---> 36     return self._request_with_params(POST, MIX_ORDER_V1_URL + '/placeOrder', params)
#      37 else:
#      38     return "pls check args "
#
# File D:\Projets_Python\Online_Bots\bitget\client.py:81, in Client._request_with_params(self, method, request_path, params, cursor)
#      80 def _request_with_params(self, method, request_path, params, cursor=False):
# ---> 81     return self._request(method, request_path, params, cursor)
#
# File D:\Projets_Python\Online_Bots\bitget\client.py:60, in Client._request(self, method, request_path, params, cursor)
#      58 # exception handle
#      59 if not str(response.status_code).startswith('2'):
# ---> 60     raise exceptions.BitgetAPIException(response)
#      61 try:
#      62     res_header = response.headers
#
# BitgetAPIException: API Request Error(code=40762): The order size is greater than the max open size

# %% [markdown]
# ## Load for backtests

# %%
df_trades_loaded = load_datas_from_file(df_filename, save_load_datas_directory, sheet_name='Trades_Results')
df_trades_loaded

# %% [markdown]
# # 5 - END

# %%
save_datas_to_file(df_filename, df, save_load_datas_directory, sheet_name='Price_History')
save_datas_to_file(df_filename, df2, save_load_datas_directory, sheet_name='Long_Price_History')

# %%
# Stop timer
end_time = datetime.utcnow()

# Calcul total duration for execution in seconds
execution_time = end_time - start_time
current_time = end_time.strftime("%d/%m/%Y %H:%M:%S")

# Show duration in seconds
print(f"Execution total duration : {execution_time} seconds")

print("                                         --- End Execution Time :", current_time, "---\n")
